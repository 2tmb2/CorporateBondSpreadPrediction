# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import Ridge, Lasso, LinearRegression
from sklearn.preprocessing import StandardScaler
from build_dataframe import build_df

# %% [markdown]
# ## 1-day Horizon

# %%
X_train, y_train, X_test, y_test = build_df(split=0.8, H=1, use_recessions=False)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
ridge = Ridge()
ridge.fit(X_train, y_train)
ridge_preds = ridge.predict(X_test)

ridge_mse = mean_squared_error(y_test, ridge_preds)
ridge_r2 = r2_score(y_test, ridge_preds)
print(f"Ridge MSE = {ridge_mse}")
print(f"Ridge R2 = {ridge_r2}")
# Out:
# Ridge MSE = 0.0010087513494617512
# Ridge R2 = 0.9898017393538805

# %%
alphas = [1.0, 0.1, 0.01, 0.001, 0.0001, 0.00001]

best_mse = np.inf
best_r2  = None
best_alpha = None
for alpha in alphas:
    lasso = Lasso(alpha=alpha, max_iter=10000)
    lasso.fit(X_train, y_train)
    lasso_preds = lasso.predict(X_test)

    lasso_mse = mean_squared_error(y_test, lasso_preds)
    lasso_r2 = r2_score(y_test, lasso_preds)
    nonzero = (lasso.coef_ != 0).sum()
    print(f"alpha={alpha:<8} MSE={lasso_mse:.6f}  R2={lasso_r2:.6f}  nonzero coefs={nonzero}/{len(lasso.coef_)}")

    if lasso_mse < best_mse:
        best_mse, best_r2, best_alpha = lasso_mse, lasso_r2, alpha

print(f"\nLasso MSE = {best_mse}")
print(f"Lasso R2 = {best_r2}")
print(f"(best alpha = {best_alpha})")
# Out:
# alpha=1.0      MSE=0.180687  R2=-0.826711  nonzero coefs=0/31
# alpha=0.1      MSE=0.006448  R2=0.934816  nonzero coefs=1/31
# alpha=0.01     MSE=0.000977  R2=0.990125  nonzero coefs=1/31
# alpha=0.001    MSE=0.000929  R2=0.990606  nonzero coefs=3/31
# alpha=0.0001   MSE=0.000959  R2=0.990306  nonzero coefs=12/31
# alpha=1e-05    MSE=0.000993  R2=0.989962  nonzero coefs=18/31
#
# Lasso MSE = 0.0009291866085066004
# Lasso R2 = 0.9906061218877275
# (best alpha = 0.001)

# %%
linear = LinearRegression()
linear.fit(X_train, y_train)
linear_preds = linear.predict(X_test)

linear_mse = mean_squared_error(y_test, linear_preds)
linear_r2 = r2_score(y_test, linear_preds)
print(f"Linear MSE = {linear_mse}")
print(f"Linear R2 = {linear_r2}")
# Out:
# Linear MSE = 0.0009682174523131747
# Linear R2 = 0.9902115283949011

# %% [markdown]
# ## 7-day Horizon

# %%
X_train, y_train, X_test, y_test = build_df(split=0.8, H=7)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
ridge = Ridge()
ridge.fit(X_train, y_train)
ridge_preds = ridge.predict(X_test)

ridge_mse = mean_squared_error(y_test, ridge_preds)
ridge_r2 = r2_score(y_test, ridge_preds)
print(f"Ridge MSE = {ridge_mse}")
print(f"Ridge R2 = {ridge_r2}")
# Out:
# Ridge MSE = 0.01145379173351097
# Ridge R2 = 0.8841937121203595

# %%
alphas = [1.0, 0.1, 0.01, 0.001, 0.0001, 0.00001]

best_mse = np.inf
best_r2  = None
best_alpha = None
for alpha in alphas:
    lasso = Lasso(alpha=alpha, max_iter=10000)
    lasso.fit(X_train, y_train)
    lasso_preds = lasso.predict(X_test)

    lasso_mse = mean_squared_error(y_test, lasso_preds)
    lasso_r2 = r2_score(y_test, lasso_preds)
    nonzero = (lasso.coef_ != 0).sum()
    print(f"alpha={alpha:<8} MSE={lasso_mse:.6f}  R2={lasso_r2:.6f}  nonzero coefs={nonzero}/{len(lasso.coef_)}")

    if lasso_mse < best_mse:
        best_mse, best_r2, best_alpha = lasso_mse, lasso_r2, alpha

print(f"\nLasso MSE = {best_mse}")
print(f"Lasso R2 = {best_r2}")
print(f"(best alpha = {best_alpha})")
# Out:
# alpha=1.0      MSE=0.180907  R2=-0.829101  nonzero coefs=0/31
# alpha=0.1      MSE=0.011632  R2=0.882391  nonzero coefs=1/31
# alpha=0.01     MSE=0.006689  R2=0.932366  nonzero coefs=2/31
# alpha=0.001    MSE=0.007484  R2=0.924331  nonzero coefs=14/31
# alpha=0.0001   MSE=0.009136  R2=0.907630  nonzero coefs=17/31
# alpha=1e-05    MSE=0.011466  R2=0.884073  nonzero coefs=24/31
#
# Lasso MSE = 0.006689358430261549
# Lasso R2 = 0.932365649199079
# (best alpha = 0.01)

# %%
linear = LinearRegression()
linear.fit(X_train, y_train)
linear_preds = linear.predict(X_test)

linear_mse = mean_squared_error(y_test, linear_preds)
linear_r2 = r2_score(y_test, linear_preds)
print(f"Linear MSE = {linear_mse}")
print(f"Linear R2 = {linear_r2}")
# Out:
# Linear MSE = 0.009844543525211974
# Linear R2 = 0.9004643992094937

# %% [markdown]
# ## 28-day Horizon

# %%
X_train, y_train, X_test, y_test = build_df(split=0.8, H=28)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
ridge = Ridge()
ridge.fit(X_train, y_train)
ridge_preds = ridge.predict(X_test)

ridge_mse = mean_squared_error(y_test, ridge_preds)
ridge_r2 = r2_score(y_test, ridge_preds)
print(f"Ridge MSE = {ridge_mse}")
print(f"Ridge R2 = {ridge_r2}")
# Out:
# Ridge MSE = 0.10296752904838609
# Ridge R2 = -0.04138512701411767

# %%
alphas = [1.0, 0.1, 0.01, 0.001, 0.0001, 0.00001]

best_mse = np.inf
best_r2  = None
best_alpha = None
for alpha in alphas:
    lasso = Lasso(alpha=alpha, max_iter=10000)
    lasso.fit(X_train, y_train)
    lasso_preds = lasso.predict(X_test)

    lasso_mse = mean_squared_error(y_test, lasso_preds)
    lasso_r2 = r2_score(y_test, lasso_preds)
    nonzero = (lasso.coef_ != 0).sum()
    print(f"alpha={alpha:<8} MSE={lasso_mse:.6f}  R2={lasso_r2:.6f}  nonzero coefs={nonzero}/{len(lasso.coef_)}")

    if lasso_mse < best_mse:
        best_mse, best_r2, best_alpha = lasso_mse, lasso_r2, alpha

print(f"\nLasso MSE = {best_mse}")
print(f"Lasso R2 = {best_r2}")
print(f"(best alpha = {best_alpha})")
# Out:
# alpha=1.0      MSE=0.181959  R2=-0.840283  nonzero coefs=0/31
# alpha=0.1      MSE=0.027621  R2=0.720646  nonzero coefs=1/31
# alpha=0.01     MSE=0.026309  R2=0.733917  nonzero coefs=5/31
# alpha=0.001    MSE=0.044199  R2=0.552982  nonzero coefs=18/31
# alpha=0.0001   MSE=0.088803  R2=0.101872  nonzero coefs=25/31
# alpha=1e-05    MSE=0.100992  R2=-0.021403  nonzero coefs=28/31
#
# Lasso MSE = 0.026309096560672467
# Lasso R2 = 0.7339170696172783
# (best alpha = 0.01)
# /Users/harrison/Documents/CSSE415/CorporateBondSpreadPrediction/.venv/lib/python3.14/site-packages/sklearn/linear_model/_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.271e+01, tolerance: 3.002e-01
#   model = cd_fast.enet_coordinate_descent(

# %%
linear = LinearRegression()
linear.fit(X_train, y_train)
linear_preds = linear.predict(X_test)

linear_mse = mean_squared_error(y_test, linear_preds)
linear_r2 = r2_score(y_test, linear_preds)
print(f"Linear MSE = {linear_mse}")
print(f"Linear R2 = {linear_r2}")
# Out:
# Linear MSE = 0.07799573542223436
# Linear R2 = 0.21117269113960413
